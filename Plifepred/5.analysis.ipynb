# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_orig = pd.read_csv("plifepred.csv")
df_mod = pd.read_csv("plifepred_mod.csv")
df_nomod = pd.read_csv("plifepred_nomod.csv")
#estos son a partir de los no modificados
df_canon = pd.read_csv("plifepred_nomod_canon.csv")
df_nocanon = pd.read_csv("plifepred_nomod_notcanon.csv")

# %%
df_orig.shape, df_mod.shape, df_nomod.shape, df_canon.shape, df_nocanon.shape
# Out:
# ((248, 4), (56, 4), (178, 4), (175, 2), (3, 2))

# %%
df_orig.describe()
# Out:
#        half_life_seconds
# count         248.000000
# mean         8642.228629
# std         20561.539970
# min            22.000000
# 25%           344.100000
# 50%           895.800000
# 75%          5400.000000
# max        172800.000000

# %%
df_mod.describe()
# Out:
#        half_life_seconds
# count          56.000000
# mean         9617.892857
# std         16099.560660
# min           120.000000
# 25%           663.000000
# 50%          2817.000000
# 75%          7785.000000
# max         66960.000000

# %%
df_nomod.describe()
# Out:
#        half_life_seconds  modifications
# count         178.000000            0.0
# mean         8530.473596            NaN
# std         22454.812749            NaN
# min            22.000000            NaN
# 25%           315.000000            NaN
# 50%           652.500000            NaN
# 75%          4200.000000            NaN
# max        172800.000000            NaN

# %%
df_canon.describe()
# Out:
#        half_life_seconds
# count         175.000000
# mean         8281.920571
# std         22447.464284
# min            22.000000
# 25%           307.500000
# 50%           639.000000
# 75%          3639.000000
# max        172800.000000

# %%
df_nocanon.describe()
# Out:
#        half_life_seconds
# count           3.000000
# mean        23029.400000
# std         21547.639339
# min           328.200000
# 25%         12944.100000
# 50%         25560.000000
# 75%         34380.000000
# max         43200.000000

# %%
sns.histplot(df_orig['half_life_seconds'], bins=10, color='skyblue', kde=False)

plt.xlabel('Vida media (segundos)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Vida Media (Plifepred)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='half_life_seconds', data=df_mod)
plt.title('Boxplot de Vida Media (Plifepred)')
plt.xlabel('Vida media (segundos)')
plt.show()

# %%
sns.histplot(df_canon['half_life_seconds'], bins=10, color='skyblue', kde=False)

plt.xlabel('Vida media (segundos)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Vida Media (Plifepred)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='half_life_seconds', data=df_canon)
plt.title('Boxplot de Vida Media (Plifepred)')
plt.xlabel('Vida media (segundos)')
plt.show()

# %%
sns.histplot(df_nocanon['half_life_seconds'], bins=10, color='skyblue', kde=False)

plt.xlabel('Vida media (segundos)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Vida Media (Plifepred)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='half_life_seconds', data=df_nocanon)
plt.title('Boxplot de Vida Media (Plifepred)')
plt.xlabel('Vida media (segundos)')
plt.show()
