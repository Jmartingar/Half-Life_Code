# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_orig = pd.read_csv("serum.csv")
df_mod = pd.read_csv("serum_mod.csv")
df_nomod = pd.read_csv("serum_nomod.csv")
#estos son a partir de los no modificados
df_canon = pd.read_csv("serum_nomod_canon.csv")
df_nocanon = pd.read_csv("serum_nomod_notcanon.csv")

# %%
df_orig.shape, df_mod.shape, df_nomod.shape, df_canon.shape, df_nocanon.shape
# Out:
# ((187, 5), (157, 4), (70, 4), (18, 2), (52, 2))

# %%
df_orig.describe()
# Out:
#        half_life_seconds
# count         187.000000
# mean        32032.408556
# std         67825.052639
# min            14.400000
# 25%          1299.000000
# 50%          7200.000000
# 75%         29880.000000
# max        432000.000000

# %%
df_mod.describe()
# Out:
#        half_life_seconds
# count       1.570000e+02
# mean        4.251508e+04
# std         1.411662e+05
# min         6.000000e+01
# 25%         2.700000e+03
# 50%         1.080000e+04
# 75%         2.880000e+04
# max         1.571760e+06

# %%
df_nomod.describe()
# Out:
#        half_life_seconds  modifications
# count          70.000000            0.0
# mean        25481.777143            NaN
# std         66389.888524            NaN
# min            14.400000            NaN
# 25%          1200.000000            NaN
# 50%          3750.000000            NaN
# 75%         18000.000000            NaN
# max        489600.000000            NaN

# %%
df_canon.describe()
# Out:
#        half_life_seconds
# count          18.000000
# mean        15306.333333
# std         24019.539029
# min            18.000000
# 25%          1260.000000
# 50%          4800.000000
# 75%         14400.000000
# max         86400.000000

# %%
df_nocanon.describe()
# Out:
#        half_life_seconds
# count          52.000000
# mean        29004.046154
# std         75642.191479
# min            14.400000
# 25%          1111.500000
# 50%          3600.000000
# 75%         19050.000000
# max        489600.000000

# %%
sns.histplot(df_orig['half_life_seconds'], bins=10, color='skyblue', kde=False)

plt.xlabel('Vida media (segundos)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Vida Media (serum)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='half_life_seconds', data=df_mod)
plt.title('Boxplot de Vida Media (serum)')
plt.xlabel('Vida media (segundos)')
plt.show()

# %%
sns.histplot(df_canon['half_life_seconds'], bins=10, color='skyblue', kde=False)

plt.xlabel('Vida media (segundos)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Vida Media (serum)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='half_life_seconds', data=df_canon)
plt.title('Boxplot de Vida Media (serum)')
plt.xlabel('Vida media (segundos)')
plt.show()

# %%
sns.histplot(df_nocanon['half_life_seconds'], bins=10, color='skyblue', kde=False)

plt.xlabel('Vida media (segundos)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Vida Media (serum)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='half_life_seconds', data=df_nocanon)
plt.title('Boxplot de Vida Media (serum)')
plt.xlabel('Vida media (segundos)')
plt.show()
