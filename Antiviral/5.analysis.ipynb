# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_orig = pd.read_csv("antiviral.csv")
df_mod = pd.read_csv("antiviral_mod.csv")
df_nomod = pd.read_csv("antiviral_nomod.csv")
#estos son a partir de los no modificados
df_canon = pd.read_csv("antiviral_nomod_canon.csv")
df_nocanon = pd.read_csv("antiviral_nomod_notcanon.csv")

# %%
df_orig.shape, df_mod.shape, df_nomod.shape, df_canon.shape, df_nocanon.shape
# Out:
# ((146, 5), (43, 5), (103, 5), (93, 2), (10, 2))

# %%
df_orig.describe()
# Out:
#        half_life_seconds
# count         146.000000
# mean         4941.780822
# std         31675.110030
# min           120.000000
# 25%           120.000000
# 50%           120.000000
# 75%           120.000000
# max        360000.000000

# %%
df_mod.describe()
# Out:
#        half_life_seconds
# count          43.000000
# mean        14641.395349
# std         57490.787071
# min           120.000000
# 25%           120.000000
# 50%           120.000000
# 75%           150.000000
# max        360000.000000

# %%
df_nomod.describe()
# Out:
#        half_life_seconds  modifications
# count         103.000000            0.0
# mean          892.427184            NaN
# std          3016.059130            NaN
# min           120.000000            NaN
# 25%           120.000000            NaN
# 50%           120.000000            NaN
# 75%           120.000000            NaN
# max         19800.000000            NaN

# %%
df_canon.describe()
# Out:
#        half_life_seconds
# count          93.000000
# mean          901.935484
# std          3153.140690
# min           120.000000
# 25%           120.000000
# 50%           120.000000
# 75%           120.000000
# max         19800.000000

# %%
df_nocanon.describe()
# Out:
#        half_life_seconds
# count          10.000000
# mean          804.000000
# std          1205.387904
# min           120.000000
# 25%           120.000000
# 50%           120.000000
# 75%          1380.000000
# max          3600.000000

# %%
sns.histplot(df_mod['half_life_seconds'], bins=10, color='skyblue', kde=False)

plt.xlabel('Vida media (segundos)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Vida Media (antiviral)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='half_life_seconds', data=df_mod)
plt.title('Boxplot de Vida Media (antiviral)')
plt.xlabel('Vida media (segundos)')
plt.show()

# %%
sns.histplot(df_canon['half_life_seconds'], bins=10, color='skyblue', kde=False)

plt.xlabel('Vida media (segundos)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Vida Media (antiviral)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='half_life_seconds', data=df_canon)
plt.title('Boxplot de Vida Media (antiviral)')
plt.xlabel('Vida media (segundos)')
plt.show()

# %%
sns.histplot(df_nocanon['half_life_seconds'], bins=10, color='skyblue', kde=False)

plt.xlabel('Vida media (segundos)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Vida Media (antiviral)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='half_life_seconds', data=df_nocanon)
plt.title('Boxplot de Vida Media (antiviral)')
plt.xlabel('Vida media (segundos)')
plt.show()
