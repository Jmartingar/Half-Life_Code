# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_orig = pd.read_csv("PEP_LIFE.csv")
df_mod = pd.read_csv("PEP_LIFE_mod.csv")
df_nomod = pd.read_csv("PEP_LIFE_nomod.csv")
#estos son a partir de los no modificados
df_canon = pd.read_csv("PEP_LIFE_nomod_canon.csv")
df_nocanon = pd.read_csv("PEP_LIFE_nomod_notcanon.csv")

# %%
df_orig.shape, df_mod.shape, df_nomod.shape, df_canon.shape, df_nocanon.shape
# Out:
# ((1110, 5), (714, 4), (225, 4), (220, 2), (5, 2))

# %%
df_orig.describe()
# Out:
#        half_life_seconds
# count       1.110000e+03
# mean        1.377784e+05
# std         3.746744e+06
# min         8.000000e-04
# 25%         1.016500e-01
# 50%         5.801000e+02
# 75%         6.405000e+03
# max         1.245673e+08

# %%
df_mod.describe()
# Out:
#        half_life_seconds
# count       7.140000e+02
# mean        2.000614e+05
# std         4.671364e+06
# min         8.000000e-04
# 25%         2.257500e-02
# 50%         3.952900e+00
# 75%         3.690000e+03
# max         1.245673e+08

# %%
df_nomod.describe()
# Out:
#        half_life_seconds  modifications
# count         225.000000            0.0
# mean        12838.033333            NaN
# std         30709.595105            NaN
# min            10.000000            NaN
# 25%           378.000000            NaN
# 50%           972.000000            NaN
# 75%          5400.000000            NaN
# max        198000.000000            NaN

# %%
df_canon.describe()
# Out:
#        half_life_seconds
# count         220.000000
# mean        12115.261364
# std         30438.701227
# min            10.000000
# 25%           366.300000
# 50%           930.000000
# 75%          5400.000000
# max        198000.000000

# %%
df_nocanon.describe()
# Out:
#        half_life_seconds
# count           5.000000
# mean        44640.000000
# std         28157.201565
# min          7200.000000
# 25%         39600.000000
# 50%         45000.000000
# 75%         45000.000000
# max         86400.000000

# %%
sns.histplot(df_orig['half_life_seconds'], bins=10, color='skyblue', kde=False)

plt.xlabel('Vida media (segundos)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Vida Media (PEP_LIFE)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='half_life_seconds', data=df_mod)
plt.title('Boxplot de Vida Media (PEP_LIFE)')
plt.xlabel('Vida media (segundos)')
plt.show()

# %%
sns.histplot(df_canon['half_life_seconds'], bins=10, color='skyblue', kde=False)

plt.xlabel('Vida media (segundos)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Vida Media (PEP_LIFE)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='half_life_seconds', data=df_canon)
plt.title('Boxplot de Vida Media (PEP_LIFE)')
plt.xlabel('Vida media (segundos)')
plt.show()

# %%
sns.histplot(df_nocanon['half_life_seconds'], bins=10, color='skyblue', kde=False)

plt.xlabel('Vida media (segundos)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Vida Media (PEP_LIFE)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='half_life_seconds', data=df_nocanon)
plt.title('Boxplot de Vida Media (PEP_LIFE)')
plt.xlabel('Vida media (segundos)')
plt.show()
