# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_orig = pd.read_csv("all_data.csv")
df_mod = pd.read_csv("all_data_mod.csv")
df_nomod = pd.read_csv("all_data_nomod.csv")
#estos son a partir de los no modificados
df_canon = pd.read_csv("all_data_nomod_canon.csv")
df_nocanon = pd.read_csv("all_data_nomod_notcanon.csv")

# %%
df_orig.shape, df_mod.shape, df_nomod.shape, df_canon.shape, df_nocanon.shape
# Out:
# ((1945, 5), (1165, 5), (405, 5), (352, 3), (53, 3))

# %%
df_orig.describe()
# Out:
#        half_life_seconds
# count       1.945000e+03
# mean        8.413155e+04
# std         2.830897e+06
# min         8.000000e-04
# 25%         5.410000e-02
# 50%         1.800000e+02
# 75%         4.878000e+03
# max         1.245673e+08

# %%
df_mod.describe()
# Out:
#        half_life_seconds
# count       1.165000e+03
# mean        1.370805e+05
# std         3.657444e+06
# min         8.000000e-04
# 25%         1.240000e-01
# 50%         9.000000e+02
# 75%         1.020000e+04
# max         1.245673e+08

# %%
df_nomod.describe()
# Out:
#        half_life_seconds  modifications
# count         405.000000            0.0
# mean         9720.387654            NaN
# std         27300.574427            NaN
# min            10.000000            NaN
# 25%           120.000000            NaN
# 50%           600.000000            NaN
# 75%          3600.000000            NaN
# max        198000.000000            NaN

# %%
df_canon.describe()
# Out:
#        half_life_seconds
# count         352.000000
# mean         8283.256818
# std         24834.188825
# min            10.000000
# 25%           120.000000
# 50%           560.700000
# 75%          3478.500000
# max        198000.000000

# %%
df_nocanon.describe()
# Out:
#        half_life_seconds
# count          53.000000
# mean        19265.105660
# std         38996.986707
# min            14.400000
# 25%           144.000000
# 50%          1800.000000
# 75%         22200.000000
# max        180000.000000

# %%
sns.histplot(df_mod['half_life_seconds'], bins=10, color='skyblue', kde=False)

plt.xlabel('Vida media (segundos)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Vida Media (All Data)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='half_life_seconds', data=df_mod)
plt.title('Boxplot de Vida Media (All Data)')
plt.xlabel('Vida media (segundos)')
plt.show()

# %%
sns.histplot(df_canon['half_life_seconds'], bins=10, color='skyblue', kde=False)

plt.xlabel('Vida media (segundos)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Vida Media (All Data)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='half_life_seconds', data=df_canon)
plt.title('Boxplot de Vida Media (All Data)')
plt.xlabel('Vida media (segundos)')
plt.show()

# %%
sns.histplot(df_nocanon['half_life_seconds'], bins=10, color='skyblue', kde=False)

plt.xlabel('Vida media (segundos)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Vida Media (All Data)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='half_life_seconds', data=df_nocanon)
plt.title('Boxplot de Vida Media (All Data)')
plt.xlabel('Vida media (segundos)')
plt.show()
