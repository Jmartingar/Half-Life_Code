# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_orig = pd.read_csv("PepTherDia.csv")
df_mod = pd.read_csv("PepTherDia_mod.csv")
df_nomod = pd.read_csv("PepTherDia_nomod.csv")
#estos son a partir de los no modificados
df_canon = pd.read_csv("PepTherDia_nomod_canon.csv")
df_nocanon = pd.read_csv("PepTherDia_nomod_notcanon.csv")

# %%
df_orig.shape, df_mod.shape, df_nomod.shape, df_canon.shape, df_nocanon.shape
# Out:
# ((42, 4), (40, 4), (0, 4), (0, 2), (0, 2))

# %%
df_orig.describe()
# Out:
#        half_life_seconds
# count       4.200000e+01
# mean        8.263929e+04
# std         2.276936e+05
# min         1.020000e+02
# 25%         2.910000e+03
# 50%         9.360000e+03
# 75%         2.677500e+04
# max         1.245600e+06

# %%
df_mod.describe()
# Out:
#        half_life_seconds
# count          40.000000
# mean        56563.350000
# std        137480.618556
# min           102.000000
# 25%          2835.000000
# 50%          9360.000000
# 75%         32130.000000
# max        619200.000000

# %%
df_nomod.describe()
# Out:
#        sequence half_life_seconds is_mod modifications
# count         0                 0      0             0
# unique        0                 0      0             0
# top         NaN               NaN    NaN           NaN
# freq        NaN               NaN    NaN           NaN

# %%
df_canon.describe()
# Out:
#        sequence half_life_seconds
# count         0                 0
# unique        0                 0
# top         NaN               NaN
# freq        NaN               NaN

# %%
df_nocanon.describe()
# Out:
#        sequence half_life_seconds
# count         0                 0
# unique        0                 0
# top         NaN               NaN
# freq        NaN               NaN

# %%
sns.histplot(df_orig['half_life_seconds'], bins=10, color='skyblue', kde=False)

plt.xlabel('Vida media (segundos)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Vida Media (PepTherDia)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='half_life_seconds', data=df_mod)
plt.title('Boxplot de Vida Media (PepTherDia)')
plt.xlabel('Vida media (segundos)')
plt.show()

# %%
sns.histplot(df_canon['half_life_seconds'], bins=10, color='skyblue', kde=False)

plt.xlabel('Vida media (segundos)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Vida Media (PepTherDia)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='half_life_seconds', data=df_canon)
plt.title('Boxplot de Vida Media (PepTherDia)')
plt.xlabel('Vida media (segundos)')
plt.show()

# %%
sns.histplot(df_nocanon['half_life_seconds'], bins=10, color='skyblue', kde=False)

plt.xlabel('Vida media (segundos)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Vida Media (PepTherDia)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='half_life_seconds', data=df_nocanon)
plt.title('Boxplot de Vida Media (PepTherDia)')
plt.xlabel('Vida media (segundos)')
plt.show()
