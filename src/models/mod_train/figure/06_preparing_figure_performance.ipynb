# %%
import warnings
warnings.filterwarnings('ignore')

import sys
sys.path.insert(0, "../")
from performance_processor import PerformanceProcessor
from get_plot import PerformanceMergerAndPlotter

# %% [markdown]
# #### Concatenate results

# %%
processor = PerformanceProcessor(
    path_results="../results/performance",
    path_export="../results/summary_exploring/"
)
processor.run()
# Out:
# Processing encoder: onehot
# ../results/performance/onehot
# ['antiviral']
# Processing encoder: FFT
# ../results/performance/FFT
# ['antiviral']
# Processing encoder: physicochemical_properties
# ../results/performance/physicochemical_properties
# ['antiviral']
# Data exported to: ../results/summary_exploring/explored_data.csv

# %% [markdown]
# #### Performance plots

# %%
input_path = "../results/summary_exploring"
output_path = "../results/summary_exploring"
input_file = "explored_data.csv"
output_file = "processed_performances.csv"

processor = PerformanceMergerAndPlotter(input_path=input_path, output_path=output_path)
processor.run(input_file, output_file)
# Out:
# Data loaded from ../results/summary_exploring/explored_data.csv
# Processed data saved to ../results/summary_exploring/processed_performances.csv
# Plotting data...
# Plots generated.
